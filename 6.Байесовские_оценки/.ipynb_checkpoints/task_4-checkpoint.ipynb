# %%
import numpy as np
import scipy.stats as sps
import matplotlib.pyplot as plt
import pylab
# %matplotlib inline

# %% [markdown]
# # Вывод формулы $E(N_t|N_s)$

# %% [markdown]
# Воспользуемся линейностью условного матожидания: <br>
#
# $E(N_t|N_s) = E([N_t-N_s]|N_s) + E(N_s|N_s) =  E([N_t-N_s]|N_s) + N_s$ <br>
#
# Известно что <br>
# $ (N_t-N_s) \sim Pois(\lambda(t-s))$ <br>
# $ (N_t-N_s)$ независимо c $N_s$ <br>
#
# Значит, $E(N_t|N_s) = E(N_t-N_s) + N_s = \lambda (t-s) + N_s$

# %%
# данные из файла
real_lambda_ = 1/95
t_0 = 500
t = 100000

data = np.loadtxt('6.csv.xls', delimiter=',', skiprows=3)

# %% [markdown]
# Распределение, сопряженное к экспоненциальному - $Г(\alpha, \beta)$. Тогда байесовская оценка параметра $\lambda$ равна $\frac{n + \alpha}{\beta + \sum_{i=1}^n \xi_i}$, <br>
# где $\xi_i$ - время между i-ым и (i + 1)-ым выходами из строя сервера. <br><br>
# Подберём параметры сопряженного распределения, для этого рассмотрим график плотности гамма распределения:

# %%
alpha_ = np.array([1, 1, 1, 2])
beta_ = np.array([1, 2, 4, 1])

x = np.linspace(0, 20, 1000)
plt.figure(figsize=(12, 8))
for i in range(4):
    plt.plot(x, sps.gamma.pdf(x, a=beta_[i], scale=1/alpha_[i]), linewidth = 1.5, 
             label = r'$\alpha = $' + str(alpha_[i]) + r' $\beta = $' + str(beta_[i]))
plt.xlim(0, 15)
plt.ylim(0, 0.5)
plt.xlabel('$t$', fontsize=20)
plt.ylabel('$q(t)$', fontsize=20)
plt.title('Плотность', fontsize=20)
plt.legend(fontsize=13)
plt.grid() 
plt.show()

# %% [markdown]
# Поскольку в начальный момент времени мы ничего не знаем о параметре $\lambda$, то нам не подходят параметры Гамма распределения, при которых образуется явный "горб" над каким-то конкретным числом. Нам следует этого избегать.
#
# Значит, нужно брать параметр $\alpha = 1$, а за параметр $\beta$ можно взять 2, при котором график плотности выглядит не очень крутым.

# %%
alpha = 1
beta = 2

# функция вычисляет действительное количество вышедших из строя серверов
# к моменту времени t, по данным из файла
def count_real_num(t):
    return np.sum(data <= t)

reality = []      # реальное число вышедших из строя серверов
prediction = []   # предсказанное число вышедших из строя серверов (по известному lambda)
time = np.arange(0, t+t_0, t_0)
for s in time:
    reality.append(count_real_num(s))
    prediction.append(count_real_num(s) + real_lambda_*(t-s))

# %% [markdown]
# Предскажем количество серверов, оценив $\lambda$:

# %%
xi = np.zeros(data.size)
xi[1:] = data[:data.size - 1]
xi = data - xi

lambda_ = np.zeros(t//t_0 + 1)
for i in range(t//t_0 + 1):
    lambda_[i] = (reality[i] + alpha) / (xi.cumsum()[reality[i] - 1] + beta)
    
result = lambda_ * (t - time) + reality

# %% [markdown]
# Вывод предсказания того, сколько серверов нужно докупить к моменту времени t:

# %%
for i in range(time.size):
    print ("Время = %d : количество серверов = %d" % (time[i], result[i]))
# Out:
# Время = 0 : количество серверов = 1
# Время = 500 : количество серверов = 1155
# Время = 1000 : количество серверов = 1409
# Время = 1500 : количество серверов = 1412
# Время = 2000 : количество серверов = 1451
# Время = 2500 : количество серверов = 1412
# Время = 3000 : количество серверов = 1215
# Время = 3500 : количество серверов = 1167
# Время = 4000 : количество серверов = 1215
# Время = 4500 : количество серверов = 1159
# Время = 5000 : количество серверов = 1235
# Время = 5500 : количество серверов = 1194
# Время = 6000 : количество серверов = 1173
# Время = 6500 : количество серверов = 1104
# Время = 7000 : количество серверов = 1117
# Время = 7500 : количество серверов = 1111
# Время = 8000 : количество серверов = 1056
# Время = 8500 : количество серверов = 1054
# Время = 9000 : количество серверов = 1119
# Время = 9500 : количество серверов = 1099
# Время = 10000 : количество серверов = 1137
# Время = 10500 : количество серверов = 1122
# Время = 11000 : количество серверов = 1144
# Время = 11500 : количество серверов = 1130
# Время = 12000 : количество серверов = 1126
# Время = 12500 : количество серверов = 1117
# Время = 13000 : количество серверов = 1099
# Время = 13500 : количество серверов = 1122
# Время = 14000 : количество серверов = 1149
# Время = 14500 : количество серверов = 1148
# Время = 15000 : количество серверов = 1153
# Время = 15500 : количество серверов = 1148
# Время = 16000 : количество серверов = 1149
# Время = 16500 : количество серверов = 1154
# Время = 17000 : количество серверов = 1147
# Время = 17500 : количество серверов = 1142
# Время = 18000 : количество серверов = 1132
# Время = 18500 : количество серверов = 1091
# Время = 19000 : количество серверов = 1103
# Время = 19500 : количество серверов = 1096
# Время = 20000 : количество серверов = 1106
# Время = 20500 : количество серверов = 1096
# Время = 21000 : количество серверов = 1117
# Время = 21500 : количество серверов = 1117
# Время = 22000 : количество серверов = 1113
# Время = 22500 : количество серверов = 1122
# Время = 23000 : количество серверов = 1129
# Время = 23500 : количество серверов = 1130
# Время = 24000 : количество серверов = 1129
# Время = 24500 : количество серверов = 1128
# Время = 25000 : количество серверов = 1120
# Время = 25500 : количество серверов = 1114
# Время = 26000 : количество серверов = 1113
# Время = 26500 : количество серверов = 1112
# Время = 27000 : количество серверов = 1113
# Время = 27500 : количество серверов = 1104
# Время = 28000 : количество серверов = 1107
# Время = 28500 : количество серверов = 1105
# Время = 29000 : количество серверов = 1101
# Время = 29500 : количество серверов = 1098
# Время = 30000 : количество серверов = 1103
# Время = 30500 : количество серверов = 1102
# Время = 31000 : количество серверов = 1097
# Время = 31500 : количество серверов = 1102
# Время = 32000 : количество серверов = 1102
# Время = 32500 : количество серверов = 1096
# Время = 33000 : количество серверов = 1097
# Время = 33500 : количество серверов = 1106
# Время = 34000 : количество серверов = 1114
# Время = 34500 : количество серверов = 1121
# Время = 35000 : количество серверов = 1125
# Время = 35500 : количество серверов = 1127
# Время = 36000 : количество серверов = 1124
# Время = 36500 : количество серверов = 1126
# Время = 37000 : количество серверов = 1124
# Время = 37500 : количество серверов = 1124
# Время = 38000 : количество серверов = 1128
# Время = 38500 : количество серверов = 1132
# Время = 39000 : количество серверов = 1128
# Время = 39500 : количество серверов = 1125
# Время = 40000 : количество серверов = 1125
# Время = 40500 : количество серверов = 1118
# Время = 41000 : количество серверов = 1121
# Время = 41500 : количество серверов = 1118
# Время = 42000 : количество серверов = 1125
# Время = 42500 : количество серверов = 1127
# Время = 43000 : количество серверов = 1128
# Время = 43500 : количество серверов = 1128
# Время = 44000 : количество серверов = 1121
# Время = 44500 : количество серверов = 1110
# Время = 45000 : количество серверов = 1114
# Время = 45500 : количество серверов = 1131
# Время = 46000 : количество серверов = 1125
# Время = 46500 : количество серверов = 1126
# Время = 47000 : количество серверов = 1140
# Время = 47500 : количество серверов = 1137
# Время = 48000 : количество серверов = 1126
# Время = 48500 : количество серверов = 1127
# Время = 49000 : количество серверов = 1133
# Время = 49500 : количество серверов = 1136
# Время = 50000 : количество серверов = 1131
# Время = 50500 : количество серверов = 1126
# Время = 51000 : количество серверов = 1118
# Время = 51500 : количество серверов = 1116
# Время = 52000 : количество серверов = 1108
# Время = 52500 : количество серверов = 1108
# Время = 53000 : количество серверов = 1114
# Время = 53500 : количество серверов = 1113
# Время = 54000 : количество серверов = 1107
# Время = 54500 : количество серверов = 1111
# Время = 55000 : количество серверов = 1110
# Время = 55500 : количество серверов = 1104
# Время = 56000 : количество серверов = 1103
# Время = 56500 : количество серверов = 1100
# Время = 57000 : количество серверов = 1113
# Время = 57500 : количество серверов = 1109
# Время = 58000 : количество серверов = 1110
# Время = 58500 : количество серверов = 1113
# Время = 59000 : количество серверов = 1112
# Время = 59500 : количество серверов = 1111
# Время = 60000 : количество серверов = 1106
# Время = 60500 : количество серверов = 1103
# Время = 61000 : количество серверов = 1102
# Время = 61500 : количество серверов = 1111
# Время = 62000 : количество серверов = 1115
# Время = 62500 : количество серверов = 1115
# Время = 63000 : количество серверов = 1111
# Время = 63500 : количество серверов = 1114
# Время = 64000 : количество серверов = 1110
# Время = 64500 : количество серверов = 1109
# Время = 65000 : количество серверов = 1111
# Время = 65500 : количество серверов = 1107
# Время = 66000 : количество серверов = 1102
# Время = 66500 : количество серверов = 1099
# Время = 67000 : количество серверов = 1098
# Время = 67500 : количество серверов = 1094
# Время = 68000 : количество серверов = 1095
# Время = 68500 : количество серверов = 1092
# Время = 69000 : количество серверов = 1089
# Время = 69500 : количество серверов = 1087
# Время = 70000 : количество серверов = 1090
# Время = 70500 : количество серверов = 1089
# Время = 71000 : количество серверов = 1089
# Время = 71500 : количество серверов = 1086
# Время = 72000 : количество серверов = 1085
# Время = 72500 : количество серверов = 1082
# Время = 73000 : количество серверов = 1083
# Время = 73500 : количество серверов = 1077
# Время = 74000 : количество серверов = 1079
# Время = 74500 : количество серверов = 1078
# Время = 75000 : количество серверов = 1075
# Время = 75500 : количество серверов = 1077
# Время = 76000 : количество серверов = 1076
# Время = 76500 : количество серверов = 1073
# Время = 77000 : количество серверов = 1072
# Время = 77500 : количество серверов = 1077
# Время = 78000 : количество серверов = 1077
# Время = 78500 : количество серверов = 1079
# Время = 79000 : количество серверов = 1080
# Время = 79500 : количество серверов = 1078
# Время = 80000 : количество серверов = 1075
# Время = 80500 : количество серверов = 1076
# Время = 81000 : количество серверов = 1075
# Время = 81500 : количество серверов = 1071
# Время = 82000 : количество серверов = 1066
# Время = 82500 : количество серверов = 1068
# Время = 83000 : количество серверов = 1062
# Время = 83500 : количество серверов = 1061
# Время = 84000 : количество серверов = 1057
# Время = 84500 : количество серверов = 1057
# Время = 85000 : количество серверов = 1055
# Время = 85500 : количество серверов = 1054
# Время = 86000 : количество серверов = 1061
# Время = 86500 : количество серверов = 1060
# Время = 87000 : количество серверов = 1057
# Время = 87500 : количество серверов = 1056
# Время = 88000 : количество серверов = 1052
# Время = 88500 : количество серверов = 1056
# Время = 89000 : количество серверов = 1056
# Время = 89500 : количество серверов = 1053
# Время = 90000 : количество серверов = 1053
# Время = 90500 : количество серверов = 1053
# Время = 91000 : количество серверов = 1051
# Время = 91500 : количество серверов = 1050
# Время = 92000 : количество серверов = 1048
# Время = 92500 : количество серверов = 1050
# Время = 93000 : количество серверов = 1054
# Время = 93500 : количество серверов = 1053
# Время = 94000 : количество серверов = 1053
# Время = 94500 : количество серверов = 1056
# Время = 95000 : количество серверов = 1052
# Время = 95500 : количество серверов = 1047
# Время = 96000 : количество серверов = 1042
# Время = 96500 : количество серверов = 1036
# Время = 97000 : количество серверов = 1031
# Время = 97500 : количество серверов = 1026
# Время = 98000 : количество серверов = 1021
# Время = 98500 : количество серверов = 1015
# Время = 99000 : количество серверов = 1010
# Время = 99500 : количество серверов = 1005
# Время = 100000 : количество серверов = 1000

# %%
plt.figure(figsize=(15,10))
plt.plot(time, result, label='предсказание с оценкой lambda')
plt.plot(time, prediction, label='предсказание с известным lambda')
plt.ylabel("Количество поломанных серверов", fontsize=17)
plt.xlabel("Время", fontsize=17)
plt.ylim((1000))
plt.legend(fontsize=17)
plt.grid() 
plt.show()

# %% [markdown]
# Построим график зависимости модуля разности значения параметра $\lambda$ и его оценки от времени.

# %%
plt.figure(figsize=(15,10))
plt.plot(time, abs(lambda_ - real_lambda_))
plt.ylabel(r'$| \lambda - \hat{\lambda}|$', fontsize = 17)
plt.xlabel("Время", fontsize=17)
plt.grid() 
plt.show()

# %% [markdown]
# # Вывод:

# %% [markdown]
# Сначала оценка плохо приближает параметр $\lambda$, но с увеличением количества считанных данных ситуация улучшается и оценка сходится.
